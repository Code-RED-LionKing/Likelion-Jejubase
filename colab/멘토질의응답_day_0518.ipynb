# %% [markdown]
# ### 1. 신입사원에게 어느정도의 능력을 요구하는지?
# @김진환 강사 — 오늘 오후 4:34
# 판다스 - 데이터 정제일
# 회사에서 만든게 있으면 코드에 맞게 수정가능해야함
#
# - EDA - 시켜봤는데 수준이 높지 않은 경우 EDA수업도 시켜주긴한다.
#
# - 처음엔 상사나 직급이 있는 분들이 짜주신 코드를 본인이 읽을수는 있어야하고 해석도 할 수 있어야 한다. 이런것이 기본역량
#
# - 인턴의 경우는 가르치키도 함
# - 처음부터 데이터 분석에 대한 코딩을 시키지는 않음 서류작성이나 기획서 준비를 하는데 정부사업이나 서류작성을 하게 되는데 이럴때는 자기 담당 사수일을 돕게되는것도 많이 하게 됨
#
# - 다양한 일을 시켜보면서 들어온 직원이 어디에 적합한지를 판단함
#
# - 코딩 실력을 확인하면서 수습기간동안의 강의를 주거나 무언가 테스트하는 것을 줌
#
# - 키우는 과정중에 회사에 도움되는 일들을 감당하게됨

# %% [markdown]
# ### 2.- 해외취업도 많이 하는지?
# - 해외취업을 원할 경우에 해외 대학원 진학이 필수인지?
# @김진환 강사— 오늘 오후 4:39
# 당연히 영어를 공부하고 계실텐데 레쥬메 추천서가 중요 - 현지 네트워크가 중요
#
# - 세계적인 네트워크가 중요 / 네트워크쪽을 잘 키우셔야함 -> 1~2년차쯤 준비하는게 더 편함
#
# - 프로젝트에 대한 어필 필요 / 공모전이나 상 / 투자정도받을정도의 수준이라면 Offer가 들어올수 있음
# - 캐글도 많이 보게 됨
#
# 김진 멘토 — 오늘 오후 4:43
# - 일상회화 수준이 아닌 비즈니스 수준의 영어가 필요 해외취업 같은 경우는 직접 가기 힘들기 때문에 비대면으로 면접을 봄 최소 3-4회의 심층 면접과 fit 이 잘 맞는지 까다롭게 봄
#
# - 일상 대화를 하면서 면접, 비자, 현지 적응 가능한지
#
# - 링크드인 활용하기 때문에 이 부분 생각하는 것도 중요
#
# ex) 미국 - 포지션을 뽑는 경우가 많음
#
# - 포트폴리오 github update
#
# - 링크드인으로 회사측에 오퍼 남기기
#
# - 대학원 진학은 비용이 비쌀 수도 있음
#
# - 외국계 데이터 분석을 한국에서도 뽑기 때문에 추후에 본사로 가기 위한 발걸음이 될 수 있음

# %% [markdown]
# ### 3. 대학원 진학관련
#
#
# 지영 멘토님은 회사생활을 하다가 대학원 진학을 결심한 계기가 뭔지 궁금합니다! 그리고 만약 회사생활을 하다 대학원을 진학할 때 전일제 vs 재직자 둘 중 뭐를 더 추천하시나요??
#
# 송지영 멘토 — 오늘 오후 4:44
# *전일제추천 -> 석사기준입니다 🙂 ㅎㅎㅎ
# 논문을 쓰고 연구하기에는 풀타임이 필요하다고 보는 입장이에요.!
# - 대학원을 가는 이유. 1- 학사/석사 승진-연봉의 욕심이 있을 때
#                     @지영멘토 : 승진하고 상사와의 소통이 필요했다. (비전공자, 컴퓨터지식없음)
# - 대학원을 가는 이유. 2-커뮤니티
# @지영멘토:  오, 저도 한양대 빅데이터 재직자전형 찾아본적 있습니다.
# 송지영 멘토 — 오늘 오후 4:51
# - 대학원을 가는 이유. 3-원하고자 하는 방향에 대한 공부

# %% [markdown]
# ### 4.EGS 분석
#
# 4.1. 관심분야가 공급망 최적화 그리고 ESG분석쪽인데 이 분야에서 데이터분석가 수요가 어느정도 되는지 궁금합니다. (이커머스/공급망관리/환경)
# 4.2. 도메인 지식도 많이 중요한지 궁금합니다. 이 부분은 지속적으로 관련 데이터셋 찾아보고 공부하면 될까요?
# 4.3. 기술적인 요소도 중요하지만 분석적인 요소가 더 중요하다고 하셨었는데, 분석적인 능력은 어떻게 연습하고 길러야 하나용
#
# https://www.google.com/search?q=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80+esg+%EC%9A%B0%EC%88%98%EC%82%AC%EB%A1%80&rlz=1C5CHFA_enKR970KR970&oq=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80+%E3%84%B8%E3%84%B4%E3%85%8E&aqs=chrome.2.69i57j0i512l9.4760j0j7&sourceid=chrome&ie=UTF-8
# 공공기관에서 많이 사례를 알리고 있어서 자주 접하고 알고 계실수록 좋을것 같아 올렸습니다.
# https://www.khnp.co.kr/main/contents.do?key=2664

# %% [markdown]
# ### 5. 취업준비
#
#
# -대개 주니어를 뽑더라도 완전 신입이 아닌 2,3년의 경력 혹은 그에 준하는 능력을 갖춘 사람을 뽑는다고 하는데,  데이터분석스쿨 수료 후 어떤 방향, 내용으로 포트폴리오를 작성하는게 좋을지 궁금합니다.
#
# -그로스해킹에 관심이 큰데, 물론 회사나 업종마다 다르겠지만 스킬을 기르고 준비하는데 있어서, 데이터분석과 마케팅 및 도메인지식 중 어느쪽에 더 초점을 맞춰야할지 궁금합니다.
#
#
# - 그 회사에 맞는 포트폴리오를 써라.
# (하나의 포트폴리오를 쓰고 회사에 맞춰서 변형해라) 스타일, 디자인등
#
# - 2,3년차 지원가능이라고 두려워하지 마라.
#
# - @김진환강사 국민은행 면접에서 3년경력차를 뽑았다. 1년 5개월을 경력으로 지원해서 합격. 채용공고를 두려워하지마라.
# - it 기업일수록 딥하게, 금융기업일수록 면접
# - 공통질문은 프로젝트를 어떻게했고 왜했고 넌 뭘했냐? 등등 꼬리질문
# - 포트폴리오가 좋아도 이런 답변을 못하게되면 안한게 된다.
# - 팀프로젝트만 잘해도 2~3년에 준하는 경력을 가지는 것이라고 생각한다
# - 현업에는 파이썬을 학생들보다 파이썬을 못하는 사람들이 존재하기도 한다.
#
# - @김진 멘토 — 오늘 오후 5:14
# - 아! 그리고 포트폴리오와 이력서는 스쿨 진행 중에도 작성하시는 것을 추천드립니다!
# 미리 작성하시면 스쿨이 진행되는 동안 피드백도 받을 수 있어 포트폴리오 및 이력서 develop이 가능합니다.

# %% [markdown]
# ### 6. AI 머신러닝 엔지니어
#
# 6.1. 기획이나 전략, CX, 마케팅 같은 부서에서 데이터분석 업무를 하다가
#    AI 머신러닝 엔지니어 같은 곳으로 나아가기 위해선 무엇이 필요한지?
#
# 6.2. 아직은 버거울 것 같다는 생각이 들지만, 이번 부트캠프를 끝내고 머신러닝 관련 직무로 바로 취업이 가능한지?
#
# - 머신러닝 -> 기획은 편하다
# - 기획 -> 머신러닝 힘들다.
# - 컴퓨터 전공이나 빅데이터 전공이아니면 바로 취업이 힘들다. (그에 준하는 실력을 가지고 있으면 가능)
# - https://modulabs.co.kr/blog/machinelearning-engineer-career/ (모두의 연구소, 머신러닝 엔지니어게 되기 위한 커리어 성장(로드맵, 강의 추천)
# - 할 수 있다라는 것을 어필 할 수 있는게 중요. 해봐야 한다

# %% [markdown]
# ### 7. 데이터분석 어떤 직군에 초첨을 맞춰야하나?
#
# -프로덕트 분석(PA)
# -비즈니스 분석(BA)
# -퍼포머스 마케터
# -CRM 마케터
# -그로스 해커 등등
# 데이터를 활용하는 것은 유사하지만, 필요 역량이나 하는일에 달라, 이러한 것들을 어떻게 선택할 수 있을지 팁이 있을까요.
#
# - 관심이 없는것을 먼저 제외하라.
#
# 7.2)위의 질문과 연관지어, 지금 함께 듣고 있는 데이터분석 캠프는 어떤 데이터 직군에 초점을 맞춘채 진행되고 있다고 봐야할까요. 사실상, 머신러닝 딥러닝은 데이터 사이언스에 초점이 맞춰진것 같다고 보면 될까요?

# %% [markdown]
# ### 8. SQL , 테블로
#
# 8.1) 데이터 분석가로서 SQL을 다룰 때,
# 단순히 쿼리를 짜는 것 외에 추가로 갖추어야 할 능력이 무엇인가요?
# DB 설계 및 관리 등의 업무도 능숙해야 하는지 궁금합니다.
#
# - 데이터 시각화 툴 테블로 보편적으로 쓰임.
# - 취업전 다루어 보는것 좋음
# - ERD 파악 중요. 어떻게 구성되어 있는지 DB관리자가 있으면 어떻게 테이블을 뽑아줘야하는지 얘기 할 수있다.
# - ERD 의 관계나 속성을 파악하는게 좋다.
# - 왜 내가 쿼리를 짜고있는가?
#
#
#
# 8.2) 실무에서 태블로와 같은 데이터 시각화 툴로 데이터를 시각화하는 상황과 파이썬으로 데이터를 시각화하는 상황의 차이는 무엇인가요?
#
# - 테블로는 마켓팅이나 여러 회사에서 사용된다
# - 파이썬은 Django(파이썬 백엔드 프레임워크)로 시각화 하는데 사용
# - 보고서를 쓸때 테블로 많이쓴다.(파이썬으로 만들기는하는데 결국 테블로로 다시만듬)
# - 기업과와 소통할때, 자주쓰는 보고서 (중간중간 보고 필요)
#
#
# 김진 멘토 — 오늘 오후 5:44
# - 어떤 쿼리를 짜야 할지 미리 정해놓고 짜시는 것도 좋아요! 저는 어떤 데이터를 뽑을 지 미리 정해놓으면 금방 쿼리문을 짤 수 있어서 좋더라고요:smile~1:
# ---
# 태블로 무료체험도 있으니 추천드립니다.
# 무료체험 하시면 전화가 오는데요. 그때 어떤 용도로 사용하였는지 여러 질문을 하더라고요. 근데 제가 사정이 있어서 제대로 사용을 못했다고 했더니 추가적으로 기간을 연장해주시더라고요!
# 그리고 추가적으로 팀원을 추가할지도 여쭤보셨어요! 팀으로 진행하신다면 팀원을 추가해서 누구에게 Creator, Viewer, Explorer를 줄지도 여쭤보셨구요!
